# %% [markdown]
# <a href="https://colab.research.google.com/github/steve-keys/ISYS5002_portfolio/blob/main/Copy_of_amazon_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kora -q

'''load packages'''

from bs4 import BeautifulSoup
from kora.selenium import wd
# Out:
#      |████████████████████████████████| 57 kB 2.8 MB/s
#      |████████████████████████████████| 56 kB 3.9 MB/s

# %%
# Establish Session
url = 'https://www.amazon.com.au'
wd.get(url)
wd
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="7efe1c7e554e6b5b161e41e14fdc1200")>

# %%
# Work out the URL pattern
template = 'https://www.amazon.com.au/s?k={}&rh=n%3A4913312051&ref=nb_sb_noss'

#search_term = 'ultrawide monitor'
search_term = input("What do you want to search for? ")

# replace spaces with a '+' SIGN
search_term = search_term.replace(' ','+')

url = template.format(search_term)
url
# Out:
# What do you want to search for? ULTRAWIDE MONITOR
# 'https://www.amazon.com.au/s?k=ULTRAWIDE+MONITOR&rh=n%3A4913312051&ref=nb_sb_noss'

# %%
search_term = input("What do you want to search for? ")
template = 'https://www.amazon.com.au/s?k={}&rh=n%3A4913312051&ref=nb_sb_noss'
search_term = search_term.replace(' ','+')
url = template.format(search_term)
wd.get(url)
wd
# Out:
# What do you want to search for? foot stool
# <selenium.webdriver.chrome.webdriver.WebDriver (session="030f83dc74b360e72e5a4508a5c1ea62")>

# %%
search_term = input("What do you want to search for? ")
template = 'https://www.amazon.com.au/s?k={}&rh=n%3A4913312051&ref=nb_sb_noss'
search_term = search_term.replace(' ','+')
url = template.format(search_term)
wd.get(url)
# Out:
# What do you want to search for? ultrawide monitor

# %%
def get_url():
  search_term = input("What do you want to search for? ")
  template = 'https://www.amazon.com.au/s?k={}&rh=n%3A4913312051&ref=nb_sb_noss'
  search_term = search_term.replace(' ','+')
  url = template.format(search_term)
  wd.get(url)

# %%
get_url
# Out:
# <function __main__.get_url>

# %% [markdown]
# # Extract the Collection

# %%
# Out:
# 48

# %% [markdown]
# # Prototype the record

# %% [markdown]
# # Generalize the pattern

# %%
records = []
results = soup.find_all('div', {'data-component-type': 's-search-result'})

for item in results:
  records.append(extract_record(item))

# %% [markdown]
# # Error Handling

# %% [markdown]
# # Find next page

# %% [markdown]
# # Putting it all together

# %%
df = amonzon_as_dataframe("ultrawide monitor")

# %%
df.head()
# Out:
#                                          description  ... review_count
# 0  Gigabyte G34WQC 34" 144Hz QHD 1ms Ultra-Wide C...  ...          198
# 1  LG 25UM58-P 25-Inch 21:9 UltraWide IPS Monitor...  ...        4,183
# 2  Dell S3221QS 32 Inch Curved 4K UHD Monitor, VA...  ...          659
# 3  BenQ 32 inch 144 Hz Curved Gaming Monitor ( EX...  ...       11,215
# 4  VIVO 17 to 43 inch Aluminum Single Ultrawide M...  ...          174
#
# [5 rows x 5 columns]
